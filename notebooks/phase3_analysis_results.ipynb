# %% [markdown]
# # Fase 3: Análisis de Resultados (Dashboard) - Granular
#
# Visualización detallada de la proyección semántica con **Ortogonalización Simétrica de Löwdin**.
# Esto garantiza independencia matemática entre las dimensiones Funcional, Social y Afectiva sin sesgos.
#
# **Marcadores**:
# - **Línea Sólida / Círculo**: Anclaje Contextual (Uso Real).
# - **Línea Punteada / Cruz**: Anclaje Estático (Diccionario).
#
# **Colores**:
# - **Azul**: Funcional
# - **Verde**: Social
# - **Rojo**: Afectiva

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

results_path = '../data/phase3_results.parquet'

if os.path.exists(results_path):
    df = pd.read_parquet(results_path)
    print(f"Resultados cargados: {len(df)} ventanas.")
    print("Columnas disponibles:", df.columns.tolist())
else:
    print("ERROR: Resultados no encontrados.")
# Out:
# Resultados cargados: 11 ventanas.
# Columnas disponibles: ['window_start_month', 'window_end_month', 'window_size_months', 'step_months', 'n_occurrences', 'n_documents', 'low_density', 'centroid_proj_funcional_baseline_penultimate_raw', 'centroid_proj_social_baseline_penultimate_raw', 'centroid_proj_afectiva_baseline_penultimate_raw', 'subspace_proj_funcional_baseline_penultimate_raw', 'subspace_proj_social_baseline_penultimate_raw', 'subspace_proj_afectiva_baseline_penultimate_raw', 'centroid_proj_funcional_baseline_penultimate_corrected', 'centroid_proj_social_baseline_penultimate_corrected', 'centroid_proj_afectiva_baseline_penultimate_corrected', 'subspace_proj_funcional_baseline_penultimate_corrected', 'subspace_proj_social_baseline_penultimate_corrected', 'subspace_proj_afectiva_baseline_penultimate_corrected', 'centroid_proj_funcional_baseline_last4_concat_raw', 'centroid_proj_social_baseline_last4_concat_raw', 'centroid_proj_afectiva_baseline_last4_concat_raw', 'subspace_proj_funcional_baseline_last4_concat_raw', 'subspace_proj_social_baseline_last4_concat_raw', 'subspace_proj_afectiva_baseline_last4_concat_raw', 'centroid_proj_funcional_baseline_last4_concat_corrected', 'centroid_proj_social_baseline_last4_concat_corrected', 'centroid_proj_afectiva_baseline_last4_concat_corrected', 'subspace_proj_funcional_baseline_last4_concat_corrected', 'subspace_proj_social_baseline_last4_concat_corrected', 'subspace_proj_afectiva_baseline_last4_concat_corrected', 'centroid_proj_funcional_dapt_penultimate_raw', 'centroid_proj_social_dapt_penultimate_raw', 'centroid_proj_afectiva_dapt_penultimate_raw', 'subspace_proj_funcional_dapt_penultimate_raw', 'subspace_proj_social_dapt_penultimate_raw', 'subspace_proj_afectiva_dapt_penultimate_raw', 'centroid_proj_funcional_dapt_penultimate_corrected', 'centroid_proj_social_dapt_penultimate_corrected', 'centroid_proj_afectiva_dapt_penultimate_corrected', 'subspace_proj_funcional_dapt_penultimate_corrected', 'subspace_proj_social_dapt_penultimate_corrected', 'subspace_proj_afectiva_dapt_penultimate_corrected', 'centroid_proj_funcional_dapt_last4_concat_raw', 'centroid_proj_social_dapt_last4_concat_raw', 'centroid_proj_afectiva_dapt_last4_concat_raw', 'subspace_proj_funcional_dapt_last4_concat_raw', 'subspace_proj_social_dapt_last4_concat_raw', 'subspace_proj_afectiva_dapt_last4_concat_raw', 'centroid_proj_funcional_dapt_last4_concat_corrected', 'centroid_proj_social_dapt_last4_concat_corrected', 'centroid_proj_afectiva_dapt_last4_concat_corrected', 'subspace_proj_funcional_dapt_last4_concat_corrected', 'subspace_proj_social_dapt_last4_concat_corrected', 'subspace_proj_afectiva_dapt_last4_concat_corrected', 'k_baseline_penultimate', 'entropy_baseline_penultimate', 'drift_baseline_penultimate', 'procrustes_baseline_penultimate', 'subspace_path_baseline_penultimate', 'centroid_proj_funcional_baseline_penultimate', 'subspace_proj_funcional_baseline_penultimate', 'centroid_proj_social_baseline_penultimate', 'subspace_proj_social_baseline_penultimate', 'centroid_proj_afectiva_baseline_penultimate', 'subspace_proj_afectiva_baseline_penultimate', 'k_baseline_last4_concat', 'entropy_baseline_last4_concat', 'drift_baseline_last4_concat', 'procrustes_baseline_last4_concat', 'subspace_path_baseline_last4_concat', 'centroid_proj_funcional_baseline_last4_concat', 'subspace_proj_funcional_baseline_last4_concat', 'centroid_proj_social_baseline_last4_concat', 'subspace_proj_social_baseline_last4_concat', 'centroid_proj_afectiva_baseline_last4_concat', 'subspace_proj_afectiva_baseline_last4_concat', 'k_dapt_penultimate', 'entropy_dapt_penultimate', 'drift_dapt_penultimate', 'procrustes_dapt_penultimate', 'subspace_path_dapt_penultimate', 'centroid_proj_funcional_dapt_penultimate', 'subspace_proj_funcional_dapt_penultimate', 'centroid_proj_social_dapt_penultimate', 'subspace_proj_social_dapt_penultimate', 'centroid_proj_afectiva_dapt_penultimate', 'subspace_proj_afectiva_dapt_penultimate', 'k_dapt_last4_concat', 'entropy_dapt_last4_concat', 'drif ...

# %% [markdown]
# ## 1. Evolución de la Posición Central (Centroide)
# ¿Hacia qué temas se mueve el discurso general sobre Yape?

# %%
def plot_projection_row(df, metric_prefix, title_prefix):
    fig, axes = plt.subplots(1, 3, figsize=(18, 5), sharey=True, sharex=True)
    
    dims = {
        'funcional': {'color': 'blue', 'ax': axes[0]},
        'social': {'color': 'green', 'ax': axes[1]},
        'afectiva': {'color': 'red', 'ax': axes[2]}
    }
    
    for dim_name, props in dims.items():
        ax = props['ax']
        color = props['color']
        
        # Contextual
        col_ctx = f'{metric_prefix}{dim_name}_contextual'
        if col_ctx in df.columns:
            ax.plot(df['date'], df[col_ctx], 
                    color=color, linestyle='-', marker='o', label='Contextual (Uso)')
        
        # Static
        col_sta = f'{metric_prefix}{dim_name}_static'
        if col_sta in df.columns:
            ax.plot(df['date'], df[col_sta], 
                    color=color, linestyle='--', marker='x', alpha=0.6, label='Estático (Teórico)')
            
        ax.set_title(f"{dim_name.upper()}")
        ax.grid(True, alpha=0.3)
        ax.tick_params(axis='x', rotation=45)
        if dim_name == 'funcional':
            ax.set_ylabel("Proyección (Similitud)")
            ax.legend()

    plt.suptitle(f"{title_prefix} - Comparativa por Dimensión Teórica", fontsize=16)
    plt.tight_layout()
    plt.show()

# Plot Centroid
plot_projection_row(df, 'score_centroid_', 'CENTROIDE (Posición Global)')

# %% [markdown]
# ## 2. Alineamiento de la Estructura Latente (Dimensión 1)
# ¿Qué significa la dimensión principal de varianza de Yape? ¿Es funcional, social o afectiva?

# %%
plot_projection_row(df, 'score_dim1_', 'DIMENSIÓN LATENTE 1 (Eje Principal)')
# Out:
# C:\Users\alvar\AppData\Local\Temp\ipykernel_18420\2043752524.py:31: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %% [markdown]
# ## 3. Alineamiento de la Estructura Latente (Dimensión 2)
# ¿Qué significa la segunda dimensión?

# %%
plot_projection_row(df, 'score_dim2_', 'DIMENSIÓN LATENTE 2 (Eje Secundario)')
# Out:
# C:\Users\alvar\AppData\Local\Temp\ipykernel_18420\2043752524.py:31: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
